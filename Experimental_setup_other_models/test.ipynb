# %%
import cleanrl
print(cleanrl.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 import cleanrl
# ----> 2 print(cleanrl.__version__)
#
# AttributeError: module 'cleanrl' has no attribute '__version__'
